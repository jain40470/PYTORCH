# %% [markdown]
# # LSTM => NEXT WORD PREDICTION (MANY TO ONE)
# # LSTM => NAMED ENTITY RECOGNITION (MANY TO MANY (FIXED))
# # CNN_LSTM => IMAGE CAPTIONING
# # ENCODER - DECODER (MACHINE TRANSLATION) (lstm based)
